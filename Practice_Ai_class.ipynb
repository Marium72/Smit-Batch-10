# %% [markdown]
# <a href="https://colab.research.google.com/github/Marium72/Smit-Batch-10/blob/master/Practice_Ai_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exercises:

# %%
#1.Fav numbers

# %%
favourite_numbers={
    "Ali":7,
    "Salman":6,
    "Daniyal":2,
    "Abbas":1,
    "Bilal":5
}

# %%
print(f"Ali's favourite number is {favourite_numbers["Ali"]}")
print(f"Salman's favourite number is {favourite_numbers["Salman"]}")
print(f"Daniyal's favourite number is {favourite_numbers["Daniyal"]}")
print(f"Abbas's favourite number is {favourite_numbers["Abbas"]}")
print(f"Bilal's favourite number is {favourite_numbers["Bilal"]}")
# Out:
# Ali's favourite number is 7
# Salman's favourite number is 6
# Daniyal's favourite number is 2
# Abbas's favourite number is 1
# Bilal's favourite number is 5

# %%
#2.Famous Quote

# %%
favourite_Quote={"Martin Luther King":"Faith is taking the first step even when you dont see the whole staircase."}

# %%
favourite_Quote
# Out:
# {'Martin Luther King': 'Faith is taking the first step even when you dont see the whole staircase.'}

# %%
#3.Buffet

# %%
buffet_tuple=("biryani","karahi","tikka","nihari","pulao")

# %%
for i in buffet_tuple:
  print(i)
if "haleem" not in buffet_tuple:
  print(f"haleem is not available")
else:
  print(f"haleem is available")
# Out:
# biryani
# karahi
# tikka
# nihari
# pulao
# haleem is not available

# %%
list_buffet=buffet_tuple=list(buffet_tuple)
list_buffet[3:5]=["pizza" , "samosa"]
print(list_buffet)
# Out:
# ['biryani', 'karahi', 'tikka', 'pizza', 'samosa']
